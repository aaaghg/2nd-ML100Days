# %% [markdown]
# ## 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# [Google Play Store Apps](https://www.kaggle.com/lava18/google-play-store-apps)
#
# #### 1. 你選的這組資料為何重要
# 這組資料包含了將近10k個App在google play store上的13種特徵，可用來觀察受User青睞的App通常具備那些條件。
#
# #### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 從Google Play Store使用網路抓取(Web scraping)而來
#
# #### 3. 蒐集而來的資料型態為何
# csv表格中，包含了數值(Rating、Reviews、Size、Installs、Price、Current Ver、Adroid Ver)、文字(App、Category、Type、Content Rating、Genres)、日期(Last Updated)，等資料
#
# #### 4. 這組資料想解決的問題如何評估
# 可以用簡單的EDA分析Rating高與Rating低的App之間的差異
#
#
#
# ## 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 提升業績有許多面向，這裡定義提升業績為提升接單數量。
# 假設若能在當前時間推薦司機，至附近可能有叫車需求的地點，便能更有機會提升接單數量。
#
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# __過去載客訂單：__ 以真實發生的交易訂單作為評估的參考，資料可從App載客歷史紀錄取得<br>
# __大眾交通工具統計資料：__ 較多人進出站的大眾交通工具會有較多人潮，便會有較大機率搭車，資料可從捷運、台鐵、高鐵的官方網站取得<br>
# __氣候：__ 當地氣候可能影響搭車意願，氣候資料可從中央氣象局觀測資料查詢系統取得<br>
#
# #### 3. 蒐集而來的資料型態為何
# __過去載客訂單：__ 可為csv表格，包含時間、地點、距離、金額等。<br>
# __大眾交通工具統計資料：__ csv表格，包含各站站名、日期、與進出站人數等。<br>
# __氣候：__ csv表格，包含各觀測站地點、日期、氣溫、降雨量等。<br>
#
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 按一定比例對上述三樣資料做預測地點的加權，將預測地點與當前地點的距離分級距(例如:100公尺、500公尺、一公里...等)，預測當前時間在各地點能載到客人的機率，提供司機做參考。
#
#
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum(pow(y - yp, 2)) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 213.316
# The Mean absolute error is 11.722
